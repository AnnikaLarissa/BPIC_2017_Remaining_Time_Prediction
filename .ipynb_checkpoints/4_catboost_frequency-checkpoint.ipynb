# %% [markdown]
# # Catboost predictor - Frequency encoded
# Implemented version of the catboost model predictor model with one-hot encoding

# %%
# import basic libraries
import pandas as pd

# import machine learning libraries
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#import catboost
from catboost import CatBoostRegressor

# %%
#import the data
X_train = pd.read_csv("data/generated/frequency/X_train.csv")
y_train = pd.read_csv("data/generated/frequency/y_train.csv")
X_test = pd.read_csv("data/generated/frequency/X_test.csv")
y_test = pd.read_csv("data/generated/frequency/y_test.csv")
X_test.head(50)
# Out:
#     Unnamed: 0       Action org:resource  \
# 0      1080782      Created      User_54
# 1      1080783      Created      User_54
# 2      1080784     Obtained      User_54
# 3      1080785  statechange      User_54
# 4      1080786  statechange      User_54
# 5      1080787      Created      User_54
# 6      1080788  statechange      User_54
# 7      1080789  statechange      User_54
# 8      1080790      Deleted      User_54
# 9      1080791      Created      User_54
# 10     1080792     Obtained      User_54
# 11     1080793  statechange      User_54
# 12     1080794     Released      User_54
# 13     1080795      Deleted       User_1
# 14     1080796      Created       User_1
# 15     1080797  statechange       User_1
# 16     1080798  statechange       User_1
# 17     1080799      Deleted       User_1
# 18     1080800      Created      User_28
# 19     1080801      Created      User_28
# 20     1080802     Obtained      User_28
# 21     1080803  statechange      User_28
# 22     1080804  statechange      User_28
# 23     1080805      Created      User_28
# 24     1080806  statechange      User_28
# 25     1080807  statechange      User_28
# 26     1080808      Deleted      User_28
# 27     1080809      Created      User_28
# 28     1080810     Obtained      User_28
# 29     1080811  statechange      User_28
# 30     1080812     Released      User_28
# 31     1080813      Deleted       User_1
# 32     1080814      Created       User_1
# 33     1080815      Deleted     User_123
# 34     1080816      Created     User_123
# 35     1080817     Obtained     User_123
# 36     1080818  statechange     User_123
# 37     1080819  statechange     User_123
# 38     1080820      Deleted     User_123
# 39     1080821      Created     User_123
# 40     1080822     Obtained     User_123
# 41     1080823  statechange     User_123
# 42     1080824     Released     User_123
# 43     1080825      Deleted     User_121
# 44     1080826      Created     User_121
# 45     1080827     Obtained     User_121
# 46     1080828  statechange     User_121
# 47     1080829     Released     User_121
# 48     1080830     Obtained      User_83
# 49     1080831     Released      User_83
#
#                                          concept:name  EventOrigin  \
# 0                                A_Create Application  Application
# 1          A_Create ApplicationW_Complete application     Workflow
# 2   A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 3   A_Create ApplicationW_Complete applicationW_Co...  Application
# 4   A_Create ApplicationW_Complete applicationW_Co...  Application
# 5   A_Create ApplicationW_Complete applicationW_Co...        Offer
# 6   A_Create ApplicationW_Complete applicationW_Co...        Offer
# 7   A_Create ApplicationW_Complete applicationW_Co...        Offer
# 8   A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 9   A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 10  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 11  A_Create ApplicationW_Complete applicationW_Co...  Application
# 12  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 13  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 14  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 15  A_Create ApplicationW_Complete applicationW_Co...  Application
# 16  A_Create ApplicationW_Complete applicationW_Co...        Offer
# 17  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 18                               A_Create Application  Application
# 19         A_Create ApplicationW_Complete application     Workflow
# 20  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 21  A_Create ApplicationW_Complete applicationW_Co...  Application
# 22  A_Create ApplicationW_Complete applicationW_Co...  Application
# 23  A_Create ApplicationW_Complete applicationW_Co...        Offer
# 24  A_Create ApplicationW_Complete applicationW_Co...        Offer
# 25  A_Create ApplicationW_Complete applicationW_Co...        Offer
# 26  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 27  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 28  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 29  A_Create ApplicationW_Complete applicationW_Co...  Application
# 30  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 31  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 32  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 33  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 34  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 35  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 36  A_Create ApplicationW_Complete applicationW_Co...  Application
# 37  A_Create ApplicationW_Complete applicationW_Co...        Offer
# 38  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 39  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 40  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 41  A_Create ApplicationW_Complete applicationW_Co...  Application
# 42  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 43  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 44  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 45  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 46  A_Create ApplicationW_Complete applicationW_Co...  Application
# 47  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 48  A_Create ApplicationW_Complete applicationW_Co...     Workflow
# 49  A_Create ApplicationW_Complete applicationW_Co...     Workflow
#
#                    EventID lifecycle:transition  \
# 0    Application_796205430             complete
# 1      Workitem_1369226671             schedule
# 2      Workitem_1550461371                start
# 3      ApplState_293815231             complete
# 4     ApplState_1815775481             complete
# 5          Offer_399297264             complete
# 6    OfferState_1589699485             complete
# 7    OfferState_2089218629             complete
# 8       Workitem_225326741             complete
# 9       Workitem_216769643             schedule
# 10     Workitem_1486976494                start
# 11     ApplState_928443164             complete
# 12     Workitem_1408864226              suspend
# 13      Workitem_816301511            ate_abort
# 14     Workitem_1738098422             schedule
# 15      ApplState_26530797             complete
# 16   OfferState_1608752089             complete
# 17      Workitem_124006819             withdraw
# 18  Application_1352841261             complete
# 19     Workitem_1920279030             schedule
# 20     Workitem_2016541263                start
# 21    ApplState_1842177426             complete
# 22    ApplState_1143402972             complete
# 23         Offer_218215250             complete
# 24   OfferState_1663819343             complete
# 25   OfferState_1196023569             complete
# 26     Workitem_1617190036             complete
# 27      Workitem_591180817             schedule
# 28      Workitem_225764488                start
# 29    ApplState_1110556040             complete
# 30      Workitem_595955187              suspend
# 31     Workitem_1615028521            ate_abort
# 32     Workitem_1294325071             schedule
# 33     Workitem_1061293030             withdraw
# 34     Workitem_1683284898             schedule
# 35      Workitem_988079210                start
# 36     ApplState_234972619             complete
# 37    OfferState_159004984             complete
# 38      Workitem_907332351             complete
# 39     Workitem_1677769580             schedule
# 40     Workitem_1934838673                start
# 41    ApplState_1023567859             complete
# 42     Workitem_1228147797              suspend
# 43      Workitem_352839852            ate_abort
# 44       Workitem_36707556             schedule
# 45     Workitem_1250346693                start
# 46    ApplState_1979212104             complete
# 47      Workitem_556522782              suspend
# 48     Workitem_1985336417               resume
# 49      Workitem_588464215              suspend
#
#                       time:timestamp     case:LoanGoal case:ApplicationType  \
# 0   2016-11-22 09:22:17.274000+00:00           Unknown           New credit
# 1   2016-11-22 09:22:17.285000+00:00           Unknown           New credit
# 2   2016-11-22 09:22:17.288000+00:00           Unknown           New credit
# 3   2016-11-22 09:22:17.291000+00:00           Unknown           New credit
# 4   2016-11-22 09:24:43.370000+00:00           Unknown           New credit
# 5   2016-11-22 09:25:50.242000+00:00           Unknown           New credit
# 6   2016-11-22 09:25:50.921000+00:00           Unknown           New credit
# 7   2016-11-22 09:26:06.138000+00:00           Unknown           New credit
# 8   2016-11-22 09:26:06.151000+00:00           Unknown           New credit
# 9   2016-11-22 09:26:06.160000+00:00           Unknown           New credit
# 10  2016-11-22 09:26:06.162000+00:00           Unknown           New credit
# 11  2016-11-22 09:26:06.167000+00:00           Unknown           New credit
# 12  2016-11-22 09:31:10.999000+00:00           Unknown           New credit
# 13  2016-11-26 06:32:01.988000+00:00           Unknown           New credit
# 14  2016-11-26 06:32:01.995000+00:00           Unknown           New credit
# 15  2016-12-23 07:00:39.242000+00:00           Unknown           New credit
# 16  2016-12-23 07:00:39.261000+00:00           Unknown           New credit
# 17  2016-12-23 07:00:39.268000+00:00           Unknown           New credit
# 18  2016-11-22 09:23:45.078000+00:00  Home improvement           New credit
# 19  2016-11-22 09:23:45.092000+00:00  Home improvement           New credit
# 20  2016-11-22 09:23:45.098000+00:00  Home improvement           New credit
# 21  2016-11-22 09:23:45.105000+00:00  Home improvement           New credit
# 22  2016-11-22 09:25:48.889000+00:00  Home improvement           New credit
# 23  2016-11-22 09:26:49.485000+00:00  Home improvement           New credit
# 24  2016-11-22 09:26:50.150000+00:00  Home improvement           New credit
# 25  2016-11-22 09:27:31.449000+00:00  Home improvement           New credit
# 26  2016-11-22 09:27:31.460000+00:00  Home improvement           New credit
# 27  2016-11-22 09:27:31.465000+00:00  Home improvement           New credit
# 28  2016-11-22 09:27:31.467000+00:00  Home improvement           New credit
# 29  2016-11-22 09:27:31.468000+00:00  Home improvement           New credit
# 30  2016-11-22 09:30:10.163000+00:00  Home improvement           New credit
# 31  2016-11-26 06:32:58.374000+00:00  Home improvement           New credit
# 32  2016-11-26 06:32:58.380000+00:00  Home improvement           New credit
# 33  2016-11-30 10:40:40.518000+00:00  Home improvement           New credit
# 34  2016-11-30 10:40:40.523000+00:00  Home improvement           New credit
# 35  2016-11-30 10:40:40.525000+00:00  Home improvement           New credit
# 36  2016-11-30 10:40:41.428000+00:00  Home improvement           New credit
# 37  2016-11-30 10:40:53.223000+00:00  Home improvement           New credit
# 38  2016-11-30 10:42:29.697000+00:00  Home improvement           New credit
# 39  2016-11-30 10:42:29.702000+00:00  Home improvement           New credit
# 40  2016-11-30 10:42:29.704000+00:00  Home improvement           New credit
# 41  2016-11-30 10:42:29.705000+00:00  Home improvement           New credit
# 42  2016-11-30 10:48:00.822000+00:00  Home improvement           New credit
# 43  2016-12-02 11:09:26.988000+00:00  Home improvement           New credit
# 44  2016-12-02 11:09:26.993000+00:00  Home improvement           New credit
# 45  2016-12-02 11:09:26.995000+00:00  Home improvement           New credit
# 46  2016-12-02 11:09:27.098000+00:00  Home improvement           New credit
# 47  2016-12-02 11:11:16.872000+00:00  Home improvement           New credit
# 48  2016-12-05 07:50:07.379000+00:00  Home improvement           New credit
# 49  2016-12-05 07:50:23.624000+00:00  Home improvement           New credit
#
#     ... OfferedAmount          OfferID  event_index_in_trace  year month  day  \
# 0   ...           NaN              NaN                     0  2016    11   22
# 1   ...           NaN              NaN                     1  2016    11   22
# 2   ...           NaN              NaN                     2  2016    11   22
# 3   ...           NaN              NaN                     3  2016    11   22
# 4   ...           NaN              NaN                     4  2016    11   22
# 5   ...        7300.0              NaN                     5  2016    11   22
# 6   ...           NaN  Offer_399297264                     6  2016    11   22
# 7   ...           NaN  Offer_399297264                     7  2016    11   22
# 8   ...           NaN              NaN                     8  2016    11   22
# 9   ...           NaN              NaN                     9  2016    11   22
# 10  ...           NaN              NaN                    10  2016    11   22
# 11  ...           NaN              NaN                    11  2016    11   22
# 12  ...           NaN              NaN                    12  2016    11   22
# 13  ...           NaN              NaN                    13  2016    11   26
# 14  ...           NaN              NaN                    14  2016    11   26
# 15  ...           NaN              NaN                    15  2016    12   23
# 16  ...           NaN  Offer_399297264                    16  2016    12   23
# 17  ...           NaN              NaN                    17  2016    12   23
# 18  ...           NaN              NaN                     0  2016    11   22
# 19  ...           NaN              NaN                     1  2016    11   22
# 20  ...           NaN              NaN                     2  2016    11   22
# 21  ...           NaN              NaN                     3  2016    11   22
# 22  ...           NaN              NaN                     4  2016    11   22
# 23  ...       20000.0              NaN                     5  2016    11   22
# 24  ...           NaN  Offer_218215250                     6  2016    11   22
# 25  ...           NaN  Offer_218215250                     7  2016    11   22
# 26  ...           NaN              NaN                     8  2016    11   22
# 27  ...           NaN              NaN                     9  2016    11   22
# 28  ...           NaN              NaN                    10  2016    11   22
# 29  ...           NaN              NaN                    11  2016    11   22
# 30  ...           NaN              NaN                    12  2016    11   22
# 31  ...           NaN              NaN                    13  2016    11   26
# 32  ...           NaN              NaN                    14  2016    11   26
# 33  ...           NaN              NaN                    15  2016    11   30
# 34  ...           NaN              NaN                    16  2016    11   30
# 35  ...           NaN              NaN                    17  2016    11   30
# 36  ...           NaN              NaN                    18  2016    11   30
# 37  ...           NaN  Offer_218215250                    19  2016    11   30
# 38  ...           NaN              NaN                    20  2016    11   30
# 39  ...           NaN              NaN                    21  2016    11   30
# 40  ...           NaN              NaN                    22  2016    11   30
# 41  ...           NaN              NaN                    23  2016    11   30
# 42  ...           NaN              NaN                    24  2016    11   30
# 43  ...           NaN              NaN                    25  2016    12    2
# 44  ...           NaN              NaN                    26  2016    12    2
# 45  ...           NaN              NaN                    27  2016    12    2
# 46  ...           NaN              NaN                    28  2016    12    2
# 47  ...           NaN              NaN                    29  2016    12    2
# 48  ...           NaN              NaN                    30  2016    12    5
# 49  ...           NaN              NaN                    31  2016    12    5
#
#    hour  minute  second microsecond
# 0     9      22      17      274000
# 1     9      22      17      285000
# 2     9      22      17      288000
# 3     9      22      17      291000
# 4     9      24      43      370000
# 5     9      25      50      242000
# 6     9      25      50      921000
# 7     9      26       6      138000
# 8     9      26       6      151000
# 9     9      26       6      160000
# 10    9      26       6      162000
# 11    9      26       6      167000
# 12    9      31      10      999000
# 13    6      32       1      988000
# 14    6      32       1      995000
# 15    7       0      39      242000
# 16    7       0      39      261000
# 17    7       0      39      268000
# 18    9      23      45       78000
# 19    9      23      45       92000
# 20    9      23      45       98000
# 21    9      23      45      105000
# 22    9      25      48      889000
# 23    9      26      49      485000
# 24    9      26      50      150000
# 25    9      27      31      449000
# 26    9      27      31      460000
# 27    9      27      31      465000
# 28    9      27      31      467000
# 29    9      27      31      468000
# 30    9      30      10      163000
# 31    6      32      58      374000
# 32    6      32      58      380000
# 33   10      40      40      518000
# 34   10      40      40      523000
# 35   10      40      40      525000
# 36   10      40      41      428000
# 37   10      40      53      223000
# 38   10      42      29      697000
# 39   10      42      29      702000
# 40   10      42      29      704000
# 41   10      42      29      705000
# 42   10      48       0      822000
# 43   11       9      26      988000
# 44   11       9      26      993000
# 45   11       9      26      995000
# 46   11       9      27       98000
# 47   11      11      16      872000
# 48    7      50       7      379000
# 49    7      50      23      624000
#
# [50 rows x 28 columns]

# %% [markdown]
# ### Pre-process the data

# %%
y_test = y_test['remaining_time']
y_train = y_train['remaining_time']

# %%
# Drop the offer columns
X_train = X_train.drop(['FirstWithdrawalAmount', 'NumberOfTerms', 'Accepted','MonthlyCost','Selected','CreditScore','OfferedAmount','OfferID','Unnamed: 0','time:timestamp'], axis=1)
# Drop the offer columns
X_test = X_test.drop(['FirstWithdrawalAmount', 'NumberOfTerms', 'Accepted','MonthlyCost','Selected','CreditScore','OfferedAmount','OfferID','Unnamed: 0','time:timestamp'], axis=1)

# %%
#Drop some other unnecessary columns
#X_train = X_train.drop(['Action', 'EventID','case:ApplicationType','EventOrigin','lifecycle:transition'],axis=1)

#Drop some other unnecessary columns
#X_test = X_test.drop(['Action', 'EventID','case:ApplicationType','EventOrigin','lifecycle:transition'],axis=1)

# %%
#dropping the ID column
#X_train = X_train.drop(['case:concept:name'],axis=1)
#X_test = X_test.drop(['case:concept:name'],axis=1)

# %%
# Separate categorical and numeric features

categorical_features = ['org:resource','concept:name','case:LoanGoal','case:concept:name','Action', 'EventID','case:ApplicationType','EventOrigin','lifecycle:transition']
numeric_features = X_train.columns.difference(categorical_features)

# Convert categorical features to string
X_train[categorical_features] = X_train[categorical_features].astype(str)
X_test[categorical_features] = X_test[categorical_features].astype(str)

# %%
X_test.dtypes
# Out:
# Action                   object
# org:resource             object
# concept:name             object
# EventOrigin              object
# EventID                  object
# lifecycle:transition     object
# case:LoanGoal            object
# case:ApplicationType     object
# case:concept:name        object
# case:RequestedAmount    float64
# event_index_in_trace      int64
# year                      int64
# month                     int64
# day                       int64
# hour                      int64
# minute                    int64
# second                    int64
# microsecond               int64
# dtype: object

# %% [markdown]
# ### Building the model

# %%
# Create a CatBoost regressor
model = CatBoostRegressor(iterations=500, depth=6, learning_rate=0.01, loss_function='RMSE')

# %%
# Train the model
model.fit(X_train, y_train, cat_features=categorical_features, eval_set=(X_test, y_test), early_stopping_rounds=10, verbose=10)
# Out:
# 0:	learn: 13.4422899	test: 11.9293129	best: 11.9293129 (0)	total: 1.28s	remaining: 10m 37s
# 10:	learn: 12.7055358	test: 11.5892344	best: 11.5892344 (10)	total: 5.44s	remaining: 4m 2s
# 20:	learn: 12.0634996	test: 11.2879457	best: 11.2879457 (20)	total: 8.21s	remaining: 3m 7s
# 30:	learn: 11.4921115	test: 11.0133206	best: 11.0133206 (30)	total: 14.7s	remaining: 3m 42s
# 40:	learn: 10.9633044	test: 10.8057750	best: 10.8057750 (40)	total: 22.4s	remaining: 4m 11s
# 50:	learn: 10.4898112	test: 10.6544860	best: 10.6544860 (50)	total: 29.6s	remaining: 4m 20s
# 60:	learn: 10.0784772	test: 10.5144843	best: 10.5144843 (60)	total: 34.9s	remaining: 4m 11s
# 70:	learn: 9.7215891	test: 10.3991125	best: 10.3991125 (70)	total: 42.8s	remaining: 4m 18s
# 80:	learn: 9.3957588	test: 10.2548510	best: 10.2548510 (80)	total: 48s	remaining: 4m 8s
# 90:	learn: 9.1077357	test: 10.0802255	best: 10.0802255 (90)	total: 51.4s	remaining: 3m 50s
# 100:	learn: 8.8598645	test: 9.9405842	best: 9.9405842 (100)	total: 53.3s	remaining: 3m 30s
# 110:	learn: 8.6468367	test: 9.8473544	best: 9.8473544 (110)	total: 55.6s	remaining: 3m 14s
# 120:	learn: 8.4628761	test: 9.7713337	best: 9.7713337 (120)	total: 59.2s	remaining: 3m 5s
# 130:	learn: 8.3043354	test: 9.7173318	best: 9.7173318 (130)	total: 1m 3s	remaining: 2m 58s
# 140:	learn: 8.1661914	test: 9.6767412	best: 9.6767412 (140)	total: 1m 6s	remaining: 2m 48s
# 150:	learn: 8.0475318	test: 9.6512391	best: 9.6512391 (150)	total: 1m 9s	remaining: 2m 39s
# 160:	learn: 7.9422890	test: 9.6278826	best: 9.6278826 (160)	total: 1m 13s	remaining: 2m 35s
# 170:	learn: 7.8506821	test: 9.6039844	best: 9.6039844 (170)	total: 1m 16s	remaining: 2m 27s
# 180:	learn: 7.7697586	test: 9.5937853	best: 9.5934458 (179)	total: 1m 22s	remaining: 2m 25s
# 190:	learn: 7.6996432	test: 9.5879777	best: 9.5874599 (188)	total: 1m 30s	remaining: 2m 26s
# 200:	learn: 7.6360956	test: 9.5849886	best: 9.5849886 (200)	total: 1m 37s	remaining: 2m 25s
# 210:	learn: 7.5772894	test: 9.5855123	best: 9.5848995 (201)	total: 1m 47s	remaining: 2m 26s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 9.584899455
# bestIteration = 201
#
# Shrink model to first 202 iterations.

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %% [markdown]
# ### Evaluate the model

# %%
# MSE
mean_squared_error(y_test, y_pred)
# Out:
# 91.87029750260531

# %%
# R2
r2_score(y_test, y_pred)
# Out:
# 0.3553624512171861

# %% [markdown]
# ### Feature importance

# %%
import matplotlib.pyplot as plt

# Assuming 'model' is your trained CatBoostRegressor
feature_importance = model.get_feature_importance()

# Get feature names from the original DataFrame (X_train)
feature_names = X_train.columns

# Create a DataFrame to store feature importance values with their corresponding names
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Set the threshold for visibility
threshold = 0.01  # Adjust this threshold as needed

# Filter features based on the threshold
important_features = feature_importance_df[feature_importance_df['Importance'] >= threshold]

# Sort the DataFrame by importance in descending order
important_features = important_features.sort_values(by='Importance', ascending=False)

# Plot feature importance for only the relevant features
plt.figure(figsize=(10, 6))
plt.barh(important_features['Feature'], important_features['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('CatBoost Feature Importance (Above Threshold)')
plt.show()
